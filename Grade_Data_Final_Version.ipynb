# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DATASET/Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 0       B-  ...     C-     C-     C-     C-     A-      A     C-      B
# 1       D+  ...     D+      D      C      D     A-     B-      C      C
# 2       A-  ...      B      B      A      C      A      A      A     A-
# 3        D  ...     D+      C     D+     C-     B-      B     C+     C+
# 4        A  ...     B-     B+     B+     B-     A-      A     A-     A-
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 0       A-  2.205
# 1        B  2.008
# 2        A  3.608
# 3       C+  1.906
# 4        A  3.448
# ..     ...    ...
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# 569      C  2.193
# 570     C-  1.753
#
# [571 rows x 43 columns]

# %%
df.shape
# Out:
# (571, 43)

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
#  19  CS-214     565 non-null    object
#  20  EE-217     565 non-null    object
#  21  CS-212     565 non-null    object
#  22  CS-215     565 non-null    object
#  23  MT-331     562 non-null    object
#  24  EF-303     561 non-null    object
#  25  HS-304     561 non-null    object
#  26  CS-301     561 non-null    object
#  27  CS-302     561 non-null    object
#  28  TC-383     561 non-null    object
#  29  MT-442     561 non-null    object
#  30  EL-332     562 non-null    object
#  31  CS-318     562 non-null    object
#  32  CS-306     562 non-null    object
#  33  CS-312     561 non-null    object
#  34  CS-317     559 non-null    object
#  35  CS-403     559 non-null    object
#  36  CS-421     559 non-null    object
#  37  CS-406     486 non-null    object
#  38  CS-414     558 non-null    object
#  39  CS-419     558 non-null    object
#  40  CS-423     557 non-null    object
#  41  CS-412     492 non-null    object
#  42  CGPA       571 non-null    float64
# dtypes: float64(1), object(42)
# memory usage: 191.9+ KB

# %%
df.columns.to_list()
# Out:
# ['Seat No.',
#  'PH-121',
#  'HS-101',
#  'CY-105',
#  'HS-105/12',
#  'MT-111',
#  'CS-105',
#  'CS-106',
#  'EL-102',
#  'EE-119',
#  'ME-107',
#  'CS-107',
#  'HS-205/20',
#  'MT-222',
#  'EE-222',
#  'MT-224',
#  'CS-210',
#  'CS-211',
#  'CS-203',
#  'CS-214',
#  'EE-217',
#  'CS-212',
#  'CS-215',
#  'MT-331',
#  'EF-303',
#  'HS-304',
#  'CS-301',
#  'CS-302',
#  'TC-383',
#  'MT-442',
#  'EL-332',
#  'CS-318',
#  'CS-306',
#  'CS-312',
#  'CS-317',
#  'CS-403',
#  'CS-421',
#  'CS-406',
#  'CS-414',
#  'CS-419',
#  'CS-423',
#  'CS-412',
#  'CGPA']

# %%
df.rename(columns={'HS-105/12':'HS-105','HS-205/20':'HS-205'},inplace=True)

# %%
df.columns.to_list()
# Out:
# ['Seat No.',
#  'PH-121',
#  'HS-101',
#  'CY-105',
#  'HS-105',
#  'MT-111',
#  'CS-105',
#  'CS-106',
#  'EL-102',
#  'EE-119',
#  'ME-107',
#  'CS-107',
#  'HS-205',
#  'MT-222',
#  'EE-222',
#  'MT-224',
#  'CS-210',
#  'CS-211',
#  'CS-203',
#  'CS-214',
#  'EE-217',
#  'CS-212',
#  'CS-215',
#  'MT-331',
#  'EF-303',
#  'HS-304',
#  'CS-301',
#  'CS-302',
#  'TC-383',
#  'MT-442',
#  'EL-332',
#  'CS-318',
#  'CS-306',
#  'CS-312',
#  'CS-317',
#  'CS-403',
#  'CS-421',
#  'CS-406',
#  'CS-414',
#  'CS-419',
#  'CS-423',
#  'CS-412',
#  'CGPA']

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       1
# HS-105       1
# MT-111       2
# CS-105       0
# CS-106       2
# EL-102       2
# EE-119       2
# ME-107       2
# CS-107       2
# HS-205       5
# MT-222       5
# EE-222       7
# MT-224       7
# CS-210       7
# CS-211       5
# CS-203       5
# CS-214       6
# EE-217       6
# CS-212       6
# CS-215       6
# MT-331       9
# EF-303      10
# HS-304      10
# CS-301      10
# CS-302      10
# TC-383      10
# MT-442      10
# EL-332       9
# CS-318       9
# CS-306       9
# CS-312      10
# CS-317      12
# CS-403      12
# CS-421      12
# CS-406      85
# CS-414      13
# CS-419      13
# CS-423      14
# CS-412      79
# CGPA         0
# dtype: int64

# %%
df =  df.drop(['CS-406'],axis=1)

# %%
df =  df.drop(['CS-412'],axis=1)

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       1
# HS-105       1
# MT-111       2
# CS-105       0
# CS-106       2
# EL-102       2
# EE-119       2
# ME-107       2
# CS-107       2
# HS-205       5
# MT-222       5
# EE-222       7
# MT-224       7
# CS-210       7
# CS-211       5
# CS-203       5
# CS-214       6
# EE-217       6
# CS-212       6
# CS-215       6
# MT-331       9
# EF-303      10
# HS-304      10
# CS-301      10
# CS-302      10
# TC-383      10
# MT-442      10
# EL-332       9
# CS-318       9
# CS-306       9
# CS-312      10
# CS-317      12
# CS-403      12
# CS-421      12
# CS-414      13
# CS-419      13
# CS-423      14
# CGPA         0
# dtype: int64

# %%
df.drop(columns=['Seat No.'],inplace=True)

# %%
df.isnull().mean()
# Out:
# PH-121    0.000000
# HS-101    0.000000
# CY-105    0.001751
# HS-105    0.001751
# MT-111    0.003503
# CS-105    0.000000
# CS-106    0.003503
# EL-102    0.003503
# EE-119    0.003503
# ME-107    0.003503
# CS-107    0.003503
# HS-205    0.008757
# MT-222    0.008757
# EE-222    0.012259
# MT-224    0.012259
# CS-210    0.012259
# CS-211    0.008757
# CS-203    0.008757
# CS-214    0.010508
# EE-217    0.010508
# CS-212    0.010508
# CS-215    0.010508
# MT-331    0.015762
# EF-303    0.017513
# HS-304    0.017513
# CS-301    0.017513
# CS-302    0.017513
# TC-383    0.017513
# MT-442    0.017513
# EL-332    0.015762
# CS-318    0.015762
# CS-306    0.015762
# CS-312    0.017513
# CS-317    0.021016
# CS-403    0.021016
# CS-421    0.021016
# CS-414    0.022767
# CS-419    0.022767
# CS-423    0.024518
# CGPA      0.000000
# dtype: float64

# %%
df.isnull().median()
# Out:
# PH-121    0.0
# HS-101    0.0
# CY-105    0.0
# HS-105    0.0
# MT-111    0.0
# CS-105    0.0
# CS-106    0.0
# EL-102    0.0
# EE-119    0.0
# ME-107    0.0
# CS-107    0.0
# HS-205    0.0
# MT-222    0.0
# EE-222    0.0
# MT-224    0.0
# CS-210    0.0
# CS-211    0.0
# CS-203    0.0
# CS-214    0.0
# EE-217    0.0
# CS-212    0.0
# CS-215    0.0
# MT-331    0.0
# EF-303    0.0
# HS-304    0.0
# CS-301    0.0
# CS-302    0.0
# TC-383    0.0
# MT-442    0.0
# EL-332    0.0
# CS-318    0.0
# CS-306    0.0
# CS-312    0.0
# CS-317    0.0
# CS-403    0.0
# CS-421    0.0
# CS-414    0.0
# CS-419    0.0
# CS-423    0.0
# CGPA      0.0
# dtype: float64

# %%
# for each column, get value counts in decreasing order and take the index (value) of most common class
# replaces missing data with modes

df = df.apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
df.isnull().sum()
# Out:
# PH-121    0
# HS-101    0
# CY-105    0
# HS-105    0
# MT-111    0
# CS-105    0
# CS-106    0
# EL-102    0
# EE-119    0
# ME-107    0
# CS-107    0
# HS-205    0
# MT-222    0
# EE-222    0
# MT-224    0
# CS-210    0
# CS-211    0
# CS-203    0
# CS-214    0
# EE-217    0
# CS-212    0
# CS-215    0
# MT-331    0
# EF-303    0
# HS-304    0
# CS-301    0
# CS-302    0
# TC-383    0
# MT-442    0
# EL-332    0
# CS-318    0
# CS-306    0
# CS-312    0
# CS-317    0
# CS-403    0
# CS-421    0
# CS-414    0
# CS-419    0
# CS-423    0
# CGPA      0
# dtype: int64

# %%
for i in df.columns:
    x = df[i].value_counts()
    print("\nColumn name is:",i,"and it value is:\n",x)
# Out:
# Column name is: PH-121 and it value is:
#  A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64
#
# Column name is: HS-101 and it value is:
#  A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64
#
# Column name is: CY-105 and it value is:
#  A     178
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# Name: CY-105, dtype: int64
#
# Column name is: HS-105 and it value is:
#  A     97
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105, dtype: int64
#
# Column name is: MT-111 and it value is:
#  A-    107
# A     100
# B-     70
# B+     62
# B      55
# C-     39
# C+     33
# C      30
# D      26
# A+     23
# D+     21
# WU      3
# F       2
# Name: MT-111, dtype: int64
#
# Column name is: CS-105 and it value is:
#  A     151
# A-    134
# B+     60
# B      51
# A+     43
# B-     38
# C+     23
# C      22
# C-     22
# D+     15
# D      12
# Name: CS-105, dtype: int64
#
# Column name is: CS-106 and it value is:
#  A-    118
# B+    101
# B      96
# A      56
# B-     54
# C+     41
# D+     29
# C-     27
# D      24
# C      18
# A+      4
# WU      2
# F       1
# Name: CS-106, dtype: int64
#
# Column name is: EL-102 and it value is:
#  A-    107
# A      92
# B+     69
# B      59
# B-     53
# D      38
# C+     35
# C-     32
# C      30
# A+     29
# D+     23
# WU      3
# F       1
# Name: EL-102, dtype: int64
#
# Column name is: EE-119 and it value is:
#  A-    139
# B+     83
# B      77
# A      68
# B-     48
# C      48
# C+     38
# D+     26
# C-     26
# D      11
# A+      6
# WU      1
# Name: EE-119, dtype: int64
#
# Column name is: ME-107 and it value is:
#  A-    81
# A     77
# B+    68
# D     56
# B-    56
# B     50
# C     49
# C-    48
# C+    37
# D+    37
# A+     8
# WU     2
# F      2
# Name: ME-107, dtype: int64
#
# Column name is: CS-107 and it value is:
#  A     107
# A-     81
# B+     57
# B      55
# C-     49
# B-     43
# A+     42
# D      38
# C+     34
# D+     31
# C      30
# WU      2
# I       1
# F       1
# Name: CS-107, dtype: int64
#
# Column name is: HS-205 and it value is:
#  A-    155
# A     118
# B      97
# B+     89
# B-     36
# C+     33
# C      15
# C-     11
# D+      9
# D       3
# A+      2
# F       2
# WU      1
# Name: HS-205, dtype: int64
#
# Column name is: MT-222 and it value is:
#  A-    91
# A     80
# D     66
# B     61
# B-    52
# D+    46
# C     43
# B+    42
# C+    39
# C-    30
# A+    16
# F      3
# WU     1
# W      1
# Name: MT-222, dtype: int64
#
# Column name is: EE-222 and it value is:
#  A     129
# A-    121
# B+     65
# B      53
# C      39
# B-     35
# A+     32
# C+     29
# D      25
# D+     21
# C-     16
# F       4
# W       2
# Name: EE-222, dtype: int64
#
# Column name is: MT-224 and it value is:
#  A-    127
# A      80
# B+     65
# B      57
# B-     49
# C-     43
# C+     39
# D+     37
# D      31
# C      30
# A+     10
# WU      1
# W       1
# F       1
# Name: MT-224, dtype: int64
#
# Column name is: CS-210 and it value is:
#  A-    140
# A     101
# B+     84
# B      59
# B-     58
# C      30
# C+     27
# C-     24
# D+     21
# D      12
# A+     12
# WU      1
# W       1
# F       1
# Name: CS-210, dtype: int64
#
# Column name is: CS-211 and it value is:
#  A-    73
# A     67
# B-    60
# D+    56
# B+    56
# B     56
# C+    55
# C-    50
# C     39
# D     33
# A+    21
# F      3
# WU     1
# W      1
# Name: CS-211, dtype: int64
#
# Column name is: CS-203 and it value is:
#  A-    93
# A     81
# B     66
# C+    62
# B+    59
# B-    53
# D+    39
# C     35
# C-    35
# D     30
# A+    15
# F      2
# I      1
# Name: CS-203, dtype: int64
#
# Column name is: CS-214 and it value is:
#  C     82
# A-    73
# B     63
# C-    57
# B-    56
# A     56
# D+    47
# C+    46
# B+    45
# D     31
# A+    12
# F      2
# I      1
# Name: CS-214, dtype: int64
#
# Column name is: EE-217 and it value is:
#  A-    143
# A      97
# B+     70
# B      63
# B-     57
# C      36
# C+     29
# A+     22
# C-     20
# D+     19
# D      12
# F       2
# WU      1
# Name: EE-217, dtype: int64
#
# Column name is: CS-212 and it value is:
#  A-    107
# B+     86
# B      81
# B-     65
# C      44
# A      43
# D+     36
# C+     35
# C-     35
# D      33
# A+      4
# WU      2
# Name: CS-212, dtype: int64
#
# Column name is: CS-215 and it value is:
#  A-    85
# A     68
# B     64
# B-    59
# C+    50
# B+    50
# C     48
# C-    47
# D     42
# D+    38
# A+    17
# WU     1
# W      1
# F      1
# Name: CS-215, dtype: int64
#
# Column name is: MT-331 and it value is:
#  A     127
# A-    103
# B+     64
# B      57
# B-     46
# C-     32
# D+     31
# A+     30
# C      28
# C+     27
# D      22
# F       4
# Name: MT-331, dtype: int64
#
# Column name is: EF-303 and it value is:
#  B     122
# B-     92
# C      61
# B+     59
# C+     58
# C-     56
# D+     49
# A-     38
# D      19
# A      14
# F       2
# WU      1
# Name: EF-303, dtype: int64
#
# Column name is: HS-304 and it value is:
#  A-    138
# B      72
# B-     70
# B+     66
# C      58
# C+     53
# C-     33
# A      28
# D      20
# D+     19
# F       6
# A+      4
# WU      2
# W       2
# Name: HS-304, dtype: int64
#
# Column name is: CS-301 and it value is:
#  A-    118
# B+     74
# B      71
# A      66
# B-     60
# C      41
# C+     37
# C-     36
# D      29
# D+     29
# A+      9
# F       1
# Name: CS-301, dtype: int64
#
# Column name is: CS-302 and it value is:
#  A-    123
# B     102
# A      86
# B+     81
# B-     60
# C+     32
# C      28
# D      21
# C-     19
# D+     10
# A+      9
# Name: CS-302, dtype: int64
#
# Column name is: TC-383 and it value is:
#  A     115
# A-     73
# B+     68
# B      59
# C+     44
# D+     44
# C-     42
# C      42
# B-     40
# A+     23
# D      20
# F       1
# Name: TC-383, dtype: int64
#
# Column name is: MT-442 and it value is:
#  A-    150
# A     130
# B+     65
# B      47
# A+     39
# B-     30
# C-     28
# C+     24
# C      24
# D      20
# D+     13
# F       1
# Name: MT-442, dtype: int64
#
# Column name is: EL-332 and it value is:
#  A-    105
# A      76
# B+     68
# B      67
# B-     62
# C      49
# C+     38
# C-     32
# D+     22
# D      22
# A+     20
# F       9
# WU      1
# Name: EL-332, dtype: int64
#
# Column name is: CS-318 and it value is:
#  A-    98
# B-    69
# B     68
# B+    65
# C     53
# C+    49
# A     42
# C-    40
# D     36
# D+    29
# F     10
# A+     6
# WU     5
# W      1
# Name: CS-318, dtype: int64
#
# Column name is: CS-306 and it value is:
#  A-    129
# B+     75
# A      74
# B-     64
# B      53
# C-     40
# C      37
# C+     36
# D      31
# D+     18
# A+     10
# F       3
# WU      1
# Name: CS-306, dtype: int64
#
# Column name is: CS-312 and it value is:
#  A+    103
# A      86
# A-     63
# D+     52
# C      48
# C-     44
# B+     42
# B      37
# C+     37
# B-     36
# D      19
# F       2
# W       1
# WU      1
# Name: CS-312, dtype: int64
#
# Column name is: CS-317 and it value is:
#  B-    91
# B     75
# C     70
# A-    66
# B+    58
# C+    57
# A     47
# C-    41
# D+    34
# D     16
# A+     9
# F      7
# Name: CS-317, dtype: int64
#
# Column name is: CS-403 and it value is:
#  A     145
# A-    106
# B+     62
# B-     55
# B      54
# D+     35
# C      33
# C+     32
# C-     30
# A+     15
# D       4
# Name: CS-403, dtype: int64
#
# Column name is: CS-421 and it value is:
#  B     98
# B-    74
# C     68
# C+    61
# C-    60
# B+    60
# A-    47
# D+    36
# A     25
# D     21
# F     17
# A+     2
# W      2
# Name: CS-421, dtype: int64
#
# Column name is: CS-414 and it value is:
#  A     189
# A-    156
# B+     62
# B      54
# B-     21
# A+     21
# C+     21
# C      20
# C-     12
# F       7
# D+      3
# D       3
# W       2
# Name: CS-414, dtype: int64
#
# Column name is: CS-419 and it value is:
#  A-    133
# B      89
# B+     85
# B-     78
# A      56
# C+     46
# C      40
# C-     20
# D+     13
# D       7
# A+      2
# F       2
# Name: CS-419, dtype: int64
#
# Column name is: CS-423 and it value is:
#  A-    136
# A      78
# B+     75
# B      65
# B-     56
# C      45
# C+     39
# C-     29
# D+     25
# D      15
# F       5
# A+      3
# Name: CS-423, dtype: int64
#
# Column name is: CGPA and it value is:
#  3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
#         ..
# 2.555    1
# 2.042    1
# 2.634    1
# 2.053    1
# 1.753    1
# Name: CGPA, Length: 491, dtype: int64

# %%
for i in df.columns:
    df.drop(df[(df.loc[:,i]=='WU')| (df.loc[:,i]=='W')].index,inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     PH-121 HS-101 CY-105 HS-105 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-      C     C-     D+      D     C-     B-     C-
# 1        A      D     D+      D     B-      C      D      A     D+      D
# 2        A      B      A     B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+      D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-     B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 543      B      A      A     A-     A+      A     A-     A-     A+     B+
# 544     A+      A      A      A      A      A      A     A-      A      A
# 545      B      A     A-     B+      A      A      A      A      A      B
# 546      A     B+      D      A      D     D+     B-     C-     B-     C-
# 547      C      D      D      C      C     D+      B     C+      C     D+
#
#      ... CS-318 CS-306 CS-312 CS-317 CS-403 CS-421 CS-414 CS-419 CS-423   CGPA
# 0    ...     C-      C     C-     C-     C-     C-      A     C-      B  2.205
# 1    ...     A-      D     D+      D      C      D     B-      C      C  2.008
# 2    ...     A-     A-      B      B      A      C      A      A     A-  3.608
# 3    ...     B+     C-     D+      C     D+     C-      B     C+     C+  1.906
# 4    ...     B-     A-     B-     B+     B+     B-      A     A-     A-  3.448
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 543  ...      A     B+     A-     A-      A      A     B+     B+      B  3.798
# 544  ...     A+     A-     B+     B+      A      A      B     A-      C  3.772
# 545  ...     C+     B+     A-      B      A     B+      C     B+     A-  3.470
# 546  ...     B-     B+      D      B      B     C-      C      B     B-  2.193
# 547  ...     C-     D+     C+      C     B-      D     C-     B+      D  1.753
#
# [548 rows x 40 columns]

# %%
for column in df.columns:
    
    df[column]=df[column].replace('A+',4.0)
    df[column]=df[column].replace('A',4.0)
    df[column]=df[column].replace('A-',3.7)
    df[column]=df[column].replace('B+',3.4)
    df[column]=df[column].replace('B',3.0)
    df[column]=df[column].replace('B-',2.7)
    df[column]=df[column].replace('C+',2.4)
    df[column]=df[column].replace('C',2.0)
    df[column]=df[column].replace('C-',1.7)
    df[column]=df[column].replace('D+',1.4)
    df[column]=df[column].replace('D',1.0)
    df[column]=df[column].replace('F',0.0)

# %%
df.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7     2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4     1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0     2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.4     1.4     1.0     1.0     3.7     1.4     1.7     1.0
# 4     3.7     3.7     3.7     3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107  ...  CS-318  CS-306  CS-312  CS-317  CS-403  CS-421  CS-414  \
# 0     1.7  ...     1.7     2.0     1.7     1.7     1.7     1.7     4.0
# 1     1.0  ...     3.7     1.0     1.4     1.0     2.0     1.0     2.7
# 2     3.7  ...     3.7     3.7     3.0     3.0     4.0     2.0     4.0
# 3     2.4  ...     3.4     1.7     1.4     2.0     1.4     1.7     3.0
# 4     3.7  ...     2.7     3.7     2.7     3.4     3.4     2.7     4.0
#
#    CS-419  CS-423   CGPA
# 0     1.7     3.0  2.205
# 1     2.0     2.0  2.008
# 2     4.0     3.7  3.608
# 3     2.4     2.4  1.906
# 4     3.7     3.7  3.448
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 40 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PH-121  548 non-null    float64
#  1   HS-101  548 non-null    float64
#  2   CY-105  548 non-null    float64
#  3   HS-105  548 non-null    float64
#  4   MT-111  548 non-null    float64
#  5   CS-105  548 non-null    float64
#  6   CS-106  548 non-null    float64
#  7   EL-102  548 non-null    float64
#  8   EE-119  548 non-null    float64
#  9   ME-107  548 non-null    float64
#  10  CS-107  548 non-null    float64
#  11  HS-205  548 non-null    float64
#  12  MT-222  548 non-null    float64
#  13  EE-222  548 non-null    float64
#  14  MT-224  548 non-null    float64
#  15  CS-210  548 non-null    float64
#  16  CS-211  548 non-null    float64
#  17  CS-203  548 non-null    float64
#  18  CS-214  548 non-null    float64
#  19  EE-217  548 non-null    float64
#  20  CS-212  548 non-null    float64
#  21  CS-215  548 non-null    float64
#  22  MT-331  548 non-null    float64
#  23  EF-303  548 non-null    float64
#  24  HS-304  548 non-null    float64
#  25  CS-301  548 non-null    float64
#  26  CS-302  548 non-null    float64
#  27  TC-383  548 non-null    float64
#  28  MT-442  548 non-null    float64
#  29  EL-332  548 non-null    float64
#  30  CS-318  548 non-null    float64
#  31  CS-306  548 non-null    float64
#  32  CS-312  548 non-null    float64
#  33  CS-317  548 non-null    float64
#  34  CS-403  548 non-null    float64
#  35  CS-421  548 non-null    float64
#  36  CS-414  548 non-null    float64
#  37  CS-419  548 non-null    float64
#  38  CS-423  548 non-null    float64
#  39  CGPA    548 non-null    float64
# dtypes: float64(40)
# memory usage: 171.4 KB

# %%
df.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7     2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4     1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0     2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.4     1.4     1.0     1.0     3.7     1.4     1.7     1.0
# 4     3.7     3.7     3.7     3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107  ...  CS-318  CS-306  CS-312  CS-317  CS-403  CS-421  CS-414  \
# 0     1.7  ...     1.7     2.0     1.7     1.7     1.7     1.7     4.0
# 1     1.0  ...     3.7     1.0     1.4     1.0     2.0     1.0     2.7
# 2     3.7  ...     3.7     3.7     3.0     3.0     4.0     2.0     4.0
# 3     2.4  ...     3.4     1.7     1.4     2.0     1.4     1.7     3.0
# 4     3.7  ...     2.7     3.7     2.7     3.4     3.4     2.7     4.0
#
#    CS-419  CS-423   CGPA
# 0     1.7     3.0  2.205
# 1     2.0     2.0  2.008
# 2     4.0     3.7  3.608
# 3     2.4     2.4  1.906
# 4     3.7     3.7  3.448
#
# [5 rows x 40 columns]

# %%
df['CGPA']=pd.cut(df.CGPA,bins=[0,2.5,3,3.5,4],labels=['1','2','3','4'])

# %%
df
# Out:
#      PH-121  HS-101  CY-105  HS-105  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0       2.7     1.4     1.7     2.0     1.7     1.4     1.0     1.7     2.7
# 1       4.0     1.0     1.4     1.0     2.7     2.0     1.0     4.0     1.4
# 2       4.0     3.0     4.0     2.7     3.4     4.0     2.7     3.4     3.7
# 3       1.0     2.4     1.4     1.0     1.0     3.7     1.4     1.7     1.0
# 4       3.7     3.7     3.7     3.4     4.0     4.0     3.7     3.4     4.0
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 543     3.0     4.0     4.0     3.7     4.0     4.0     3.7     3.7     4.0
# 544     4.0     4.0     4.0     4.0     4.0     4.0     4.0     3.7     4.0
# 545     3.0     4.0     3.7     3.4     4.0     4.0     4.0     4.0     4.0
# 546     4.0     3.4     1.0     4.0     1.0     1.4     2.7     1.7     2.7
# 547     2.0     1.0     1.0     2.0     2.0     1.4     3.0     2.4     2.0
#
#      ME-107  ...  CS-318  CS-306  CS-312  CS-317  CS-403  CS-421  CS-414  \
# 0       1.7  ...     1.7     2.0     1.7     1.7     1.7     1.7     4.0
# 1       1.0  ...     3.7     1.0     1.4     1.0     2.0     1.0     2.7
# 2       3.7  ...     3.7     3.7     3.0     3.0     4.0     2.0     4.0
# 3       2.4  ...     3.4     1.7     1.4     2.0     1.4     1.7     3.0
# 4       3.7  ...     2.7     3.7     2.7     3.4     3.4     2.7     4.0
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 543     3.4  ...     4.0     3.4     3.7     3.7     4.0     4.0     3.4
# 544     4.0  ...     4.0     3.7     3.4     3.4     4.0     4.0     3.0
# 545     3.0  ...     2.4     3.4     3.7     3.0     4.0     3.4     2.0
# 546     1.7  ...     2.7     3.4     1.0     3.0     3.0     1.7     2.0
# 547     1.4  ...     1.7     1.4     2.4     2.0     2.7     1.0     1.7
#
#      CS-419  CS-423  CGPA
# 0       1.7     3.0     1
# 1       2.0     2.0     1
# 2       4.0     3.7     4
# 3       2.4     2.4     1
# 4       3.7     3.7     3
# ..      ...     ...   ...
# 543     3.4     3.0     4
# 544     3.7     2.0     4
# 545     3.4     3.7     3
# 546     3.0     2.7     1
# 547     3.4     1.0     1
#
# [548 rows x 40 columns]

# %%
x= df.iloc[:,:-1]
x
# Out:
#      PH-121  HS-101  CY-105  HS-105  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0       2.7     1.4     1.7     2.0     1.7     1.4     1.0     1.7     2.7
# 1       4.0     1.0     1.4     1.0     2.7     2.0     1.0     4.0     1.4
# 2       4.0     3.0     4.0     2.7     3.4     4.0     2.7     3.4     3.7
# 3       1.0     2.4     1.4     1.0     1.0     3.7     1.4     1.7     1.0
# 4       3.7     3.7     3.7     3.4     4.0     4.0     3.7     3.4     4.0
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 543     3.0     4.0     4.0     3.7     4.0     4.0     3.7     3.7     4.0
# 544     4.0     4.0     4.0     4.0     4.0     4.0     4.0     3.7     4.0
# 545     3.0     4.0     3.7     3.4     4.0     4.0     4.0     4.0     4.0
# 546     4.0     3.4     1.0     4.0     1.0     1.4     2.7     1.7     2.7
# 547     2.0     1.0     1.0     2.0     2.0     1.4     3.0     2.4     2.0
#
#      ME-107  ...  EL-332  CS-318  CS-306  CS-312  CS-317  CS-403  CS-421  \
# 0       1.7  ...     2.0     1.7     2.0     1.7     1.7     1.7     1.7
# 1       1.0  ...     2.0     3.7     1.0     1.4     1.0     2.0     1.0
# 2       3.7  ...     3.4     3.7     3.7     3.0     3.0     4.0     2.0
# 3       2.4  ...     1.4     3.4     1.7     1.4     2.0     1.4     1.7
# 4       3.7  ...     3.7     2.7     3.7     2.7     3.4     3.4     2.7
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 543     3.4  ...     4.0     4.0     3.4     3.7     3.7     4.0     4.0
# 544     4.0  ...     4.0     4.0     3.7     3.4     3.4     4.0     4.0
# 545     3.0  ...     3.0     2.4     3.4     3.7     3.0     4.0     3.4
# 546     1.7  ...     1.0     2.7     3.4     1.0     3.0     3.0     1.7
# 547     1.4  ...     0.0     1.7     1.4     2.4     2.0     2.7     1.0
#
#      CS-414  CS-419  CS-423
# 0       4.0     1.7     3.0
# 1       2.7     2.0     2.0
# 2       4.0     4.0     3.7
# 3       3.0     2.4     2.4
# 4       4.0     3.7     3.7
# ..      ...     ...     ...
# 543     3.4     3.4     3.0
# 544     3.0     3.7     2.0
# 545     2.0     3.4     3.7
# 546     2.0     3.0     2.7
# 547     1.7     3.4     1.0
#
# [548 rows x 39 columns]

# %%
y = df.iloc[:,39]
y
# Out:
# 0      1
# 1      1
# 2      4
# 3      1
# 4      3
#       ..
# 543    4
# 544    4
# 545    3
# 546    1
# 547    1
# Name: CGPA, Length: 548, dtype: category
# Categories (4, object): ['1' < '2' < '3' < '4']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.30,random_state=1)

# %%
xtrain.head()
# Out:
#      PH-121  HS-101  CY-105  HS-105  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 545     3.0     4.0     3.7     3.4     4.0     4.0     4.0     4.0     4.0
# 218     3.7     3.7     3.7     3.0     3.7     4.0     3.0     3.7     2.7
# 80      4.0     3.4     4.0     3.7     4.0     3.7     3.4     4.0     4.0
# 46      3.7     3.4     3.7     3.7     4.0     4.0     4.0     4.0     4.0
# 537     3.4     1.7     4.0     1.4     2.4     3.7     1.7     2.4     2.4
#
#      ME-107  ...  EL-332  CS-318  CS-306  CS-312  CS-317  CS-403  CS-421  \
# 545     3.0  ...     3.0     2.4     3.4     3.7     3.0     4.0     3.4
# 218     1.7  ...     2.7     3.7     3.7     2.7     3.7     2.7     2.4
# 80      3.7  ...     4.0     3.7     3.7     3.7     4.0     3.7     3.7
# 46      2.7  ...     4.0     4.0     3.7     4.0     4.0     4.0     4.0
# 537     3.0  ...     1.0     3.4     1.0     3.4     2.0     3.4     1.7
#
#      CS-414  CS-419  CS-423
# 545     2.0     3.4     3.7
# 218     3.7     2.7     3.7
# 80      4.0     4.0     4.0
# 46      4.0     4.0     4.0
# 537     0.0     2.0     1.0
#
# [5 rows x 39 columns]

# %%
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(xtrain,ytrain)
mutual_info
# Out:
# array([0.25344716, 0.16688854, 0.22166096, 0.2769952 , 0.38137795,
#        0.16005939, 0.23573195, 0.31211858, 0.22870227, 0.25185472,
#        0.25391979, 0.09860262, 0.32374261, 0.15315158, 0.36943811,
#        0.54059077, 0.35225916, 0.22904914, 0.51889281, 0.33692287,
#        0.36705339, 0.51538915, 0.18442794, 0.24025619, 0.25010185,
#        0.43888668, 0.47548815, 0.36990695, 0.23238171, 0.42245132,
#        0.32359634, 0.4017946 , 0.19178954, 0.48977697, 0.24679273,
#        0.31522803, 0.1414495 , 0.37958609, 0.16701259])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = xtrain.columns
mutual_info.sort_values(ascending=False)*100
# Out:
# CS-210    54.059077
# CS-214    51.889281
# CS-215    51.538915
# CS-317    48.977697
# CS-302    47.548815
# CS-301    43.888668
# EL-332    42.245132
# CS-306    40.179460
# MT-111    38.137795
# CS-419    37.958609
# TC-383    36.990695
# MT-224    36.943811
# CS-212    36.705339
# CS-211    35.225916
# EE-217    33.692287
# MT-222    32.374261
# CS-318    32.359634
# CS-421    31.522803
# EL-102    31.211858
# HS-105    27.699520
# CS-107    25.391979
# PH-121    25.344716
# ME-107    25.185472
# HS-304    25.010185
# CS-403    24.679273
# EF-303    24.025619
# CS-106    23.573195
# MT-442    23.238171
# CS-203    22.904914
# EE-119    22.870227
# CY-105    22.166096
# CS-312    19.178954
# MT-331    18.442794
# CS-423    16.701259
# HS-101    16.688854
# CS-105    16.005939
# EE-222    15.315158
# CS-414    14.144950
# HS-205     9.860262
# dtype: float64

# %%
#let's plot the ordered mutual_info values per feature
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
# Out:
# <Axes: >

# %%
#No we Will select the  top 5 important features
from sklearn.feature_selection import SelectKBest
sel_ten_cols = SelectKBest(mutual_info_classif, k=15)
sel_ten_cols.fit(xtrain, ytrain)
topTen=xtrain.columns[sel_ten_cols.get_support()]

# %%
topTen
# Out:
# Index(['MT-111', 'MT-224', 'CS-210', 'CS-211', 'CS-214', 'EE-217', 'CS-215',
#        'CS-301', 'CS-302', 'TC-383', 'EL-332', 'CS-306', 'CS-317', 'CS-421',
#        'CS-419'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-414', 'CS-419', 'CS-423', 'CGPA'],
#       dtype='object')

# %%
df = df.loc[:, list(topTen) + ['CGPA']]

# %%
df
# Out:
#      MT-111  MT-224  CS-210  CS-211  CS-214  EE-217  CS-215  CS-301  CS-302  \
# 0       1.7     2.7     2.4     1.4     1.0     4.0     1.7     3.0     2.0
# 1       2.7     1.4     1.4     1.0     1.0     2.7     1.0     3.7     1.4
# 2       3.4     4.0     4.0     4.0     3.7     4.0     4.0     3.4     3.7
# 3       1.0     1.0     2.0     3.4     1.0     1.4     1.0     1.0     2.7
# 4       4.0     3.7     3.7     2.7     3.7     4.0     3.7     2.7     3.7
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 543     4.0     4.0     4.0     4.0     4.0     4.0     3.7     3.7     4.0
# 544     4.0     3.0     4.0     4.0     4.0     4.0     3.0     4.0     4.0
# 545     4.0     3.0     3.7     4.0     3.0     4.0     3.0     3.4     3.4
# 546     1.0     3.0     2.7     3.0     2.0     2.7     1.4     2.0     2.4
# 547     2.0     1.4     3.4     1.7     1.4     1.7     1.4     1.0     1.0
#
#      TC-383  EL-332  CS-306  CS-317  CS-421  CS-419 CGPA
# 0       2.4     2.0     2.0     1.7     1.7     1.7    1
# 1       1.7     2.0     1.0     1.0     1.0     2.0    1
# 2       3.0     3.4     3.7     3.0     2.0     4.0    4
# 3       1.4     1.4     1.7     2.0     1.7     2.4    1
# 4       2.4     3.7     3.7     3.4     2.7     3.7    3
# ..      ...     ...     ...     ...     ...     ...  ...
# 543     4.0     4.0     3.4     3.7     4.0     3.4    4
# 544     4.0     4.0     3.7     3.4     4.0     3.7    4
# 545     4.0     3.0     3.4     3.0     3.4     3.4    3
# 546     1.7     1.0     3.4     3.0     1.7     3.0    1
# 547     2.0     0.0     1.4     2.0     1.0     3.4    1
#
# [548 rows x 16 columns]

# %%
conditions = [
    (df['MT-224'] > 2),(df['TC-383'] > 2)
    ]

# %%
values, counts = np.unique(conditions, return_counts=True)
values,counts
# Out:
# (array([False,  True]), array([276, 820]))
